# %% [markdown]
# *This scrapping exercise is done purely for educational purposes.*
# *All videos belong to Harvard University*

# %% [markdown]
# # Code to scrape CS109 2015 videos.
#
# ## History and Motivation
#
# I'm rather unhappy with this implementation. I want to download these videos as I'll be starting work soon, and I'm not going to have the luxury of time to keep up with the course. I think I might take a few months to work through the course, and I'm worried they are going to take down the videos. I see hints that they're going to be starting a 2017 run soon. My fear is they are going to stop hosting the vids when that course starts, just as the 2013 and 2014 vids are now gone. So this is more for my own insurance and a reluctance for my learning to be beholden to anyone else's schedule.
#
# I thought it would be good practice as well, to try and scrape a website.
#
# The website design is simple enough.
#
# A [main page](https://matterhorn.dce.harvard.edu/engage/ui/index.html#/2016/01/14328) has links to [viewer](https://matterhorn.dce.harvard.edu/engage/player/watch.html?id=b721f1db-9c16-464b-bcd3-3d81e7cd13a1) pages, which nests either [one video](https://matterhorn.dce.harvard.edu/engage/player/watch.html?id=62b95e14-c296-44da-9691-446dfa313836) of the instructor or [two videos](https://matterhorn.dce.harvard.edu/engage/player/watch.html?id=e15f221c-5275-4f7f-b486-759a7d483bc8), one of the instructor and one of the slides.
#
# However, a major stumbling block to my implementation is that they used some Javascript implementation. I tried briefly to scrape the data, trying an [I'm Pythonist](https://impythonist.wordpress.com/2015/01/06/ultimate-guide-for-scraping-javascript-rendered-web-pages/) code, followed by a suggestion from [Stack Overflow](https://stackoverflow.com/questions/35241872/how-to-download-from-javascript-rendered-webpage) which was very similar and seemed to hang. There was [this](https://github.com/christopher-beckham/cs109-dl-videos) github script based off a [Quora](http://www.quora.com/Downloads/How-can-I-download-the-videos-for-CS109-Harvards-Data-Science-Course) answer, but it seemed to have been for the 2013/14 videos, and was hardcoded to those (outdated) links.
#
# Seeing that the best solution seemed to be hardcoded, I decided to bite the bullet and get the html from each page manually. This took most of my time, especially my 2GB RAM. What do. I'm sure it's possible to get python to load the webpage by masking as a browser - probably a setting buried in PyQt somewhere. Still, I managed to get this program out in one day - something I'm sure I would not have been able to do if I tried to figure that out.

# %% [markdown]
# ## How it works
#
# Recall:
#
# A [main page](https://matterhorn.dce.harvard.edu/engage/ui/index.html#/2016/01/14328) has links to [viewer](https://matterhorn.dce.harvard.edu/engage/player/watch.html?id=b721f1db-9c16-464b-bcd3-3d81e7cd13a1) pages, which nests either [one video](https://matterhorn.dce.harvard.edu/engage/player/watch.html?id=62b95e14-c296-44da-9691-446dfa313836) of the instructor or [two videos](https://matterhorn.dce.harvard.edu/engage/player/watch.html?id=e15f221c-5275-4f7f-b486-759a7d483bc8), one of the instructor and one of the slides.
#
# 1. html of **main** site saved in "h1_main.txt"
# 2. extracts all **viewer** links as a list of tuples *(name, date, link)* to "list_add.txt"
# 3. manually parse to delete unwanted links, modify names.
# 4. go to every **viewer** and save html in "Vid HTMLS/xx.html"
# 5. Extract video link(s) and save in a dict with earlier tuple as key.
# 6. Finally, begin to save videos.
#
# Modify *prefix* at point indicated to change save location.

# %%
import bs4
import urllib

# %%
with open("h1_main.txt") as h1:
    h1_main = h1.read()
har_main = bs4.BeautifulSoup(h1_main)
print har_main.prettify()

# get titles
titles = [l.get('title') for l in har_main.findAll('div', {'class':"publication-title auto-launch"})]
title_list = []
for i in titles:
    title_list.append(i[17:])

# get links
link_list = [l.get('href') for l in har_main.findAll('a', {'class':"item-link", 'data-is-default-link':"true"})]

# get dates
date_list = [l.get('data-date-time') for l in har_main.findAll('div', {'class':"pub-date ng-binding"})]
# Out:
# /home/ratio/anaconda2/lib/python2.7/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 174 of the file /home/ratio/anaconda2/lib/python2.7/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))
# <html>
#  <body>
#   <!-- Distance Education Header and banner  -->
#   <div class="banner extension" data-ng-class="{'embedded':embedded || ltitool}" id="header-banner">
#    <!-- Generalized Harvard (Summer/Extension agnostic) Header -->
#    <div class="topbar">
#     <div id="topbar-flex">
#      <a href="http://www.harvard.edu/" title="The Harvard University web page">
#       <span class="topbar__logo i-harvard-logo ir">
#        Harvard University
#       </span>
#      </a>
#      <div id="report-a-problem">
#       <a href="//cm.dce.harvard.edu/forms/report.shtml?server=MH&amp;offeringId=20160114328" title="Link to Report A Problem Form">
#        Report A
#             Problem
#       </a>
#      </div>
#     </div>
#    </div>
#   </div>
#   <!-- ngView: ng-view -->
#   <div class="ng-scope" data-ng-view="ng-view" id="listing-body">
#    <div class="container container-fluid pubData ng-scope" data-partial-name="publist">
#     <!-- title section -->
#     <div id="title-section">
#      <!-- ngIf: pubData.series.count == 1 -->
#      <div class="Harvard Extension School" data-ng-if="pubData.series.count == 1" id="dce-series">
#       <h1 class="ng-binding">
#        Data Science
#       </h1>
#       <h2>
#        <a class="dce-link ng-binding" href="http://isites.harvard.edu/course/ext-14328/2015/fall" ng-class="{'embedded':embedded || ltitool}" title="Go to CSCI E-109 course web site">
#         CSCI E-109
#        </a>
#        Publication Listing
#       </h2>
#       <div>
#       </div>
#      </div>
#      <!-- end ngIf: pubData.series.count == 1 -->
#      <!-- ngIf: ltitool -->
#     </div>
#     <!-- ngIf: iAmAdmin -->
#     <!-- System message -->
#     <!-- ngIf: sysMsg.title -->
#     <!-- END system message -->
#     <!-- ngIf: pubMessage -->
#     <!-- ngIf: !pubMessage -->
#     <div class="content body ng-scope" data-ng-if="!pubMessage">
#      <div data-ng-show="pubData.publications.length &gt; 1" id="sort-menu">
#       <label for="sort-by">
#        Sorted:
#       </label>
#       <button class="ng-pristine ng-untouched ng-valid" data-ng-model="orderProp" id="sort-by" ng-click="orderProp = { 'dateStart': '-dateStart', '-dateStart':'dateStart'}[orderProp]" title="Change sort order">
#        <div ng-show="orderProp == '-dateStart'">
#         Newest
#        </div>
#        <div class="ng-hide" ng-show="orderProp == 'dateStart'">
#         Oldest
#        </div>
#       </button>
#      </div>
#      <!--Body content-->
#      <div class="test-match-height test-rows test-responsive test-border-box test-margin test-hidden test-border">
#       <div class="items-container">
#        <!-- ngRepeat: pub in filteredPubs = (pubData.publications | orderBy:['-isLive', orderProp, '-dcType'] | pubLinkFilter:servertime | filter:query ) -->
#        <div class="item ng-scope" data-ng-repeat="pub in filteredPubs = (pubData.publications | orderBy:['-isLive', orderProp, '-dcType'] | pubLinkFilter:servertime | filter:query )" data-pub-item="data-pub-item">
#         <div class="item-element item-img auto-launch" target="_blank" title="launch video for Final Project Presentations (CAPTIONS)">
#          <img alt="Snap shot of Final Project Presentations (CAPTIONS)" class="thumb" data-item-pub="pub" data-ng-src="https://da4w749qm6awt.cloudfront.net/engage-player/b721f1db-9c16-464b-bcd3-3d81e7cd13a1/attachment-12/CSCI_109_presentations_program_12_15_15.jpg" src="https://da4w749qm6awt.cloudfront.net/engage-player/b721f1db-9c16-464b-bcd3-3d81e7cd13a1/attachment-12/CSCI_109_presentations_program_12_15_15.jpg"/>
#         </div>
#         <div class="item-text">
#          <div class="publication-details item-element">
#           <!-- ngIf: showPubSeries -->
#           <div class="publication-title auto-launch" data-item-pub="pub" target="_blank" title="launch video for Final Project Presentations (CAPTIONS)">
#            Final Project Presentations (CAPTIONS)
#            <!-- ngIf: pub.pubLabel -->
#           </div>
#           <div class="pub-date ng-binding" data-date-time="16 Dec 2:30AM">
#            Wed, 16 Dec, 2:30AM
#           </div>
#           <div class="item-details ng-binding" data-ng-bind-html="pub.notes">
#           </div>
#           <span class="hideMe" data-ng-attr-class="{{!iAmAdmin &amp;&amp; 'hideMe' || 'displayMe' }}">
#            P05
#           </span>
#           <!-- ngRepeat: link in pub.links -->
#           <div class="publication-link type-P05" data-ng-repeat="link in pub.links ">
#            <a class="item-link " data-is-default-link="true" href="https://matterhorn.dce.harvard.edu/engage/player/watch.html?id=b721f1db-9c16-464b-bcd3-3d81e7cd13a1" target="_blank">
#             <!-- ngIf: link.liveStart -->
#            </a>
#           </div>
#           <!-- end ngRepeat: link in pub.links -->
#          </div>
#         </div>
#        </div>
#        <!-- end ngRepeat: pub in filteredPubs = (pubData.publications | orderBy:['-isLive', orderProp, '-dcType'] | pubLinkFilter:servertime | filter:query ) -->
#        <div class="item ng-scope" data-ng-repeat="pub in filteredPubs = (pubData.publications | orderBy:['-isLive', orderProp, '-dcType'] | pubLinkFilter:servertime | filter:query )" data-pub-item="data-pub-item">
#         <div class="item-element item-img auto-launch" target="_blank" title="launch video for Final Project Presentations">
#          <img alt="Snap shot of Final Project Presentations" class="thumb" data-item-pub="pub" data-ng-src="https://da4w749qm6awt.cloudfront.net/engage-player/950f5075-951d-4d5c-a515-e961985d88b3/attachment-12/VGA_1450207740_SDI_A_SDI_B.jpg" src="https://da4w749qm6awt.cloudfront.net/engage-player/950f5075-951d-4d5c-a515-e961985d88b3/attachment-12/VGA_1450207740_SDI_A_SDI_B.jpg"/>
#         </div>
#         <div class="item-text">
#          <div class="publication-details item-element">
#           <!-- ngIf: showPubSeries -->
#           <div class="publication-title auto-launch" data-item-pub="pub" target="_blank" title="launch video for Final Project Presentations">
#            Final Project Presentations
#            <!-- ngIf: pub.pubLabel -->
#           </div>
#           <div class="pub-date ng-binding" data-date-time="16 Dec 2:29AM">
#            Wed, 16 Dec, 2:29AM
#           </div>
#           <div class="item-details ng-binding" data-ng-bind-html="pub.notes">
#           </div>
#           <span class="hideMe" data-ng-attr-class="{{!iAmAdmin &amp;&amp; 'hideMe' || 'displayMe' }}">
#            P05
#           </span>
#           <!-- ngRepeat: link in pub.links -->
#           <div class="publication-link type-P05" data-ng-repeat="link in pub.links ">
#            <a class="item-link " data-is-default-link="true" href="https://matterhorn.dce.harvard.edu/engage/player/watch.html?id=950f5075-951d-4d5c-a515-e961985d88b3" target="_blank">
#             <!-- ngIf: link.liveStart -->
#            </a>
#           </div>
#           <!-- end ngRepeat: link in pub.links -->
#          </div>
#         </div>
#        </div>
#        <!-- end ngRepeat: pub in filteredPubs = (pubData.publications | orderBy:['-isLive', orderProp, '-dcType'] | pubLinkFilter:servertime | filter:query ) -->
#        <div class="item ng-scope" data-ng-repeat="pub in filteredPubs = (pubData.publications | orderBy:['-isLive', orderProp, '-dcType'] | pubLinkFilter:servertime | filter:query )" data-pub-item="data-pub-item">
#         <div class="item-element item-img auto-launch" target="_blank" title="launch video for Wrap-up &amp; Outlook (CAPTIONS)">
#          <img alt="Snap shot of Wrap-up &amp; Outlook (CAPTIONS)" class="thumb" data-item-pub="pub" data-ng-src="https://da4w749qm6awt.cloudfront.net/engage-player/32a2d292-50eb-44b0-9f28-a728e515d612/attachment-12/CSCI_109_L25_program_12_03_15.jpg" src="https://da4w749qm6awt.cloudfront.net/engage-player/32a2d292-50eb-44b0-9f28-a728e515d612/attachment-12/CSCI_109_L25_program_12_03_15.jpg"/>
#         </div>
#         <div class="item-text">
#          <div class="publication-details item-element">
#           <!-- ngIf: showPubSeries -->
#           <div class="publication-title auto-launch" data-item-pub="pub" target="_blank" title="launch video for Wrap-up &amp; Outlook (CAPTIONS)">
#            Wrap-up &amp; Outlook (CAPTIONS)
#            <!-- ngIf: pub.pubLabel -->
#           </div>
#           <div class="pub-date ng-binding" data-date-time="04 Dec 2:30AM">
#            Fri, 04 Dec, 2:30AM
#           </div>
#           <div class="item-details ng-binding" data-ng-bind-html="pub.notes">
#           </div>
#           <span class="hideMe" data-ng-attr-class="{{!iAmAdmin &amp;&amp; 'hideMe' || 'displayMe' }}">
#            L25
#           </span>
#           <!-- ngRepeat: link in pub.links -->
#           <div class="publication-link type-L25" data-ng-repeat="link in pub.links ">
#            <a class="item-link " data-is-default-link="true" href="https://matterhorn.dce.harvard.edu/engage/player/watch.html?id=32a2d292-50eb-44b0-9f28-a728e515d612" target="_blank">
#             <!-- ngIf: link.liveStart -->
#            </a>
#           </div>
#           <!-- end ngRepeat: link in pub.links -->
#          </div>
#         </div>
#        </div>
#        <!-- end ngRepeat: pub in filteredPubs = (pubData.publications | orderBy:['-isLive', orderProp, '-dcType'] | pubLinkFilter:servertime | filter:query ) -->
#        <div class="item ng-scope" data-ng-repeat="pub in filteredPubs = (pubData.publications | orderBy:['-isLive', orderProp, '-dcType'] | pubLinkFilter:servertime | filter:query )" data-pub-item="data-pub-item">
#         <div class="item-element item-img auto-launch" target="_blank" title="launch video for Lecture 25">
#          <img alt="Snap shot of Lecture 25" class="thumb" data-item-pub="pub" data-ng-src="https://da4w749qm6awt.cloudfront.net/engage-player/67735f84-d3c9-406e-86cd-4bfbb38ef1cd/attachment-12/presenter_delivery.jpg" src="https://da4w749qm6awt.cloudfront.net/engage-player/67735f84-d3c9-406e-86cd-4bfbb38ef1cd/attachment-12/presenter_delivery.jpg"/>
#         </div>
#         <div class="item-text">
#          <div class="publication-details item-element">
#           <!-- ngIf: showPubSeries -->
#           <div class="publication-title auto-launch" data-item-pub="pub" target="_blank" title="launch video for Lecture 25">
#            Lecture 25
#            <!-- ngIf: pub.pubLabel -->
#           </div>
#           <div class="pub-date ng-binding" data-date-time="04 Dec 2:29AM">
#            Fri, 04 Dec, 2:29AM
#           </div>
#           <div class="item-details ng-binding" data-ng-bind-html="pub.notes">
#            Wrap-up &amp; Outlook
#           </div>
#           <span class="hideMe" data-ng-attr-class="{{!iAmAdmin &amp;&amp; 'hideMe' || 'displayMe' }}">
#            L25
#           </span>
#           <!-- ngRepeat: link in pub.links -->
#           <div class="publication-link type-L25" data-ng-repeat="link in pub.links ">
#            <a class="item-link " data-is-default-link="true" href="https://matterhorn.dce.harvard.edu/engage/player/watch.html?id=67735f84-d3c9-406e-86cd-4bfbb38ef1cd" target="_blank">
#             <!-- ngIf: link.liveStart -->
#            </a>
#           </div>
#           <!-- end ngRepeat: link in pub.links -->
#          </div>
#         </div>
#        </div>
#        <!-- end ngRepeat: pub in filteredPubs = (pubData.publications | orderBy:['-isLive', orderProp, '-dcType'] | pubLinkFilter:servertime | filter:query ) -->
#        <div class="item ng-scope" data-ng-repeat="pub in filteredPubs = (pubData.publications | orderBy:['-isLive', orderProp, '-dcType'] | pubLinkFilter:servertime | filter:query )" data-pub-item="data-pub-item">
#         <div class="item-element item-img auto-launch" target="_blank" title="launch video for Lecture 24">
#          <img alt="Snap shot of Lecture 24" class="thumb" data-item-pub="pub" data-ng-src="https://da4w749qm6awt.cloudfront.net/engage-player/128b8123-a1a6-493c-bac7-a932234374a0/attachment-12/presenter_delivery.jpg" src="https://da4w749qm6awt.cloudfront.net/engage-player/128b8123-a1a6-493c-bac7-a932234374a0/attachment-12/presenter_delivery.jpg"/>
#         </div>
#         <div class="item-text">
#          <div class="publication-details item-element">
#           <!-- ngIf: showPubSeries -->
#           <div class="publication-title auto-launch" data-item-pub="pub" target="_blank" title="launch video for Lecture 24">
#            Lecture 24
#            <!-- ngIf: pub.pubLabel -->
#           </div>
#           <div class="pub-date ng-binding" data-date-time="02 Dec 2:29AM">
#            Wed, 02 Dec, 2:29AM
#           </div>
#           <div class="item-details ng-binding" data-ng-bind-html="pub.notes">
#            Building Data Science
#           </div>
#           <span class="hideMe" data-ng-attr-class="{{!iAmAdmin &amp;&amp; 'hideMe' || 'displayMe' }}">
#            L24
#           </span>
#           <!-- ngRepeat: link in pub.links -->
#           <div class="publication-link type-L24" data-ng-repeat="link in pub.links ">
#            <a class="item-link " data-is-default-link="true" href="https://matterhorn.dce.harvard.edu/engage/player/watch.html?id=128b8123-a1a6-493c-bac7-a932234374a0" target="_blank">
#             <!-- ngIf: link.liveStart -->
#            </a>
#           </div>
#           <!-- end ngRepeat: link in pub.links -->
#          </div>
#         </div>
#        </div>
#        <!-- end ngRepeat: pub in filteredPubs = (pubData.publications | orderBy:['-isLive', orderProp, '-dcType'] | pubLinkFilter:servertime | filter:query ) -->
#        <div class="item ng-scope" data-ng-repeat="pub in filteredPubs = (pubData.publications | orderBy:['-isLive', orderProp, '-dcType'] | pubLinkFilter:servertime | filter:query )" data-pub-item="data-pub-item">
#         <div class="item-element item-img auto-launch" target="_blank" title="launch video for Deep Learning.  (CAPTIONS)">
#          <img alt="Snap shot of Deep Learning.  (CAPTIONS)" class="thumb" data-item-pub="pub" data-ng-src="https://da4w749qm6awt.cloudfront.net/engage-player/12bfea44-634f-4bc0-b88d-0aca05a3c289/attachment-12/presenter_delivery.jpg" src="https://da4w749qm6awt.cloudfront.net/engage-player/12bfea44-634f-4bc0-b88d-0aca05a3c289/attachment-12/presenter_delivery.jpg"/>
#         </div>
#         <div class="item-text">
#          <div class="publication-details item-element">
#           <!-- ngIf: showPubSeries -->
#           <div class="publication-title auto-launch" data-item-pub="pub" target="_blank" title="launch video for Deep Learning.  (CAPTIONS)">
#            Deep Learning.  (CAPTIONS)
#            <!-- ngIf: pub.pubLabel -->
#           </div>
#           <div class="pub-date ng-binding" data-date-time="20 Nov 2:30AM">
#            Fri, 20 Nov, 2:30AM
#           </div>
#           <div class="item-details ng-binding" data-ng-bind-html="pub.notes">
#           </div>
#           <span class="hideMe" data-ng-attr-class="{{!iAmAdmin &amp;&amp; 'hideMe' || 'displayMe' }}">
#            L23
#           </span>
#           <!-- ngRepeat: link in pub.links -->
#           <div class="publication-link type-L23" data-ng-repeat="link in pub.links ">
#            <a class="item-link " data-is-default-link="true" href="https://matterhorn.dce.harvard.edu/engage/player/watch.html?id=12bfea44-634f-4bc0-b88d-0aca05a3c289" target="_blank">
#             <!-- ngIf: link.liveStart -->
#            </a>
#           </div>
#           <!-- end ngRepeat: link in pub.links -->
#          </div>
#         </div>
#        </div>
#        <!-- end ngRepeat: pub in filteredPubs = (pubData.publications | orderBy:['-isLive', orderProp, '-dcType'] | pubLinkFilter:servertime | filter:query ) -->
#        <div class="item ng-scope" data-ng-repeat="pub in filteredPubs = (pubData.publications | orderBy:['-isLive', orderProp, '-dcType'] | pubLinkFilter:servertime | filter:query )" data-pub-item="data-pub-item">
#         <div class="item-element item-img auto-launch" target="_blank" title="launch video for Lecture 23">
#          <img alt="Snap shot of Lecture 23" class="thumb" data-item-pub="pub" data-ng-src="https://da4w749qm6awt.cloudfront.net/engage-player/3c8c045a-7b5b-41a1-9b96-9e07a7cfb8f5/attachment-12/presenter_delivery.jpg" src="https://da4w749qm6awt.cloudfront.net/engage-player/3c8c045a-7b5b-41a1-9b96-9e07a7cfb8f5/attachment-12/presenter_delivery.jpg"/>
#         </div>
#         <div class="item-text">
#          <div class="publication-details item-element">
#           <!-- ngIf: showPubSeries -->
#           <div class="publication-title auto-launch" data-item-pub="pub" target="_blank" title="launch video for Lecture 23">
#            Lecture 23
#            <!-- ngIf: pub.pubLabel -->
#           </div>
#           <div class="pub-date ng-binding" data-date-time="20 Nov 2:29AM">
#            Fri, 20 Nov, 2:29AM
#           </div>
#           <div class="item-details ng-binding" data-ng-bind-html="pub.notes">
#            Deep Learning.
#           </div>
#           <span class="hideMe" data-ng-attr-class="{{!iAmAdmin &amp;&amp; 'hideMe' || 'displayMe' }}">
#            L23
#           </span>
#           <!-- ngRepeat: link in pub.links -->
#           <div class="publication-link type-L23" data-ng-repeat="link in pub.links ">
#            <a class="item-link " data-is-default-link="true" href="https://matterhorn.dce.harvard.edu/engage/player/watch.html?id=3c8c045a-7b5b-41a1-9b96-9e07a7cfb8f5" target="_blank">
#             <!-- ngIf: link.liveStart -->
#            </a>
#           </div>
#           <!-- end ngRepeat: link in pub.links -->
#          </div>
#         </div>
#        </div>
#        <!-- end ngRepeat: pub in filteredPubs = (pubData.publications | orderBy:['-isLive', orderProp, '-dcType'] | pubLinkFilter:servertime | filter:query ) -->
#        <div class="item ng-scope" data-ng-repeat="pub in filteredPubs = (pubData.publications | orderBy:['-isLive', orderProp, '-dcType'] | pubLinkFilter:servertime | filter:query )" data-pub-item="data-pub-item">
#         <div class="item-element item-img auto-launch" target="_blank" title="launch video for Experimental Design. A/B testing. Tirthankar Dasgupta (CAPTIONS)">
#          <img alt="Snap shot of Experimental Design. A/B testing. Tirthankar Dasgupta (CAPTIONS)" class="thumb" data-item-pub="pub" data-ng-src="https://da4w749qm6awt.cloudfront.net/engage-player/94e52a8d-6557-48c4-b003-b5ec84d2a1e2/attachment-12/presenter_delivery.jpg" src="https://da4w749qm6awt.cloudfront.net/engage-player/94e52a8d-6557-48c4-b003-b5ec84d2a1e2/attachment-12/presenter_delivery.jpg"/>
#         </div>
#         <div class="item-text">
#          <div class="publication-details item-element">
#           <!-- ngIf: showPubSeries -->
#           <div class="publication-title auto-launch" data-item-pub="pub" target="_blank" title="launch video for Experimental Design. A/B testing. Tirthankar Dasgupta (CAPTIONS)">
#            Experimental Design. A/B testing. Tirthankar Dasgupta (CAPTIONS)
#            <!-- ngIf: pub.pubLabel -->
#           </div>
#           <div class="pub-date ng-binding" data-date-time="18 Nov 2:30AM">
#            Wed, 18 Nov, 2:30AM
#           </div>
#           <div class="item-details ng-binding" data-ng-bind-html="pub.notes">
#           </div>
#           <span class="hideMe" data-ng-attr-class="{{!iAmAdmin &amp;&amp; 'hideMe' || 'displayMe' }}">
#            L22
#           </span>
#           <!-- ngRepeat: link in pub.links -->
#           <div class="publication-link type-L22" data-ng-repeat="link in pub.links ">
#            <a class="item-link " data-is-default-link="true" href="https://matterhorn.dce.harvard.edu/engage/player/watch.html?id=94e52a8d-6557-48c4-b003-b5ec84d2a1e2" target="_blank">
#             <!-- ngIf: link.liveStart -->
#            </a>
#           </div>
#           <!-- end ngRepeat: link in pub.links -->
#          </div>
#         </div>
#        </div>
#        <!-- end ngRepeat: pub in filteredPubs = (pubData.publications | orderBy:['-isLive', orderProp, '-dcType'] | pubLinkFilter:servertime | filter:query ) -->
#        <div class="item ng-scope" data-ng-repeat="pub in filteredPubs = (pubData.publications | orderBy:['-isLive', orderProp, '-dcType'] | pubLinkFilter:servertime | filter:query )" data-pub-item="data-pub-item">
#         <div class="item-element item-img auto-launch" target="_blank" title="launch video for Lecture 22">
#          <img alt="Snap shot of Lecture 22" class="thumb" data-item-pub="pub" data-ng-src="https://da4w749qm6awt.cloudfront.net/engage-player/15117337-3199-4265-a39a-9a0c8772b9df/attachment-12/presenter_delivery.jpg" src="https://da4w749qm6awt.cloudfront.net/engage-player/15117337-3199-4265-a39a-9a0c8772b9df/attachment-12/presenter_delivery.jpg"/>
#         </div>
#         <div class="item-text">
#          <div class="publication-details item-element">
#           <!-- ngIf: showPubSeries -->
#           <div class="publication-title auto-launch" data-item-pub="pub" target="_blank" title="launch video for Lecture 22">
#            Lecture 22
#            <!-- ngIf: pub.pubLabel -->
#           </div>
#           <div class="pub-date ng-binding" data-date-time="18 Nov 2:29AM">
#            Wed, 18 Nov, 2:29AM
#           </div>
#           <div class="item-details ng-binding" data-ng-bind-html="pub.notes">
#            Experimental Design. A/B testing.Tirthankar Dasgupta
#           </div>
#           <span class="hideMe" data-ng-attr-class="{{!iAmAdmin &amp;&amp; 'hideMe' || 'displayMe' }}">
#            L22
#           </span>
#           <!-- ngRepeat: link in pub.links -->
#           <div class="publication-link type-L22" data-ng-repeat="link in pub.links ">
#            <a class="item-link " data-is-default-link="true" href="https://matterhorn.dce.harvard.edu/engage/player/watch.html?id=15117337-3199-4265-a39a-9a0c8772b9df" target="_blank">
#             <!-- ngIf: link.liveStart -->
#            </a>
#           </div>
#           <!-- end ngRepeat: link in pub.links -->
#          </div>
#         </div>
#        </div>
#        <!-- end ngRepeat: pub in filteredPubs = (pubData.publications | orderBy:['-isLive', orderProp, '-dcType'] | pubLinkFilter:servertime | filter:query ) -->
#        <div class="item ng-scope" data-ng-repeat="pub in filteredPubs = (pubData.publications | orderBy:['-isLive', orderProp, '-dcType'] | pubLinkFilter:servertime | filter:query )" data-pub-item="data-pub-item">
#         <div class="item-element item-img auto-launch" target="_blank" title="launch video for Effective Presentations. (CAPTIONS)">
#          <img alt="Snap shot of Effective Presentations. (CAPTIONS)" class="thumb" data-item-pub="pub" data-ng-src="https://da4w749qm6awt.cloudfront.net/engage-player/34758fd3-9896-4461-966a-7971e349fee3/attachment-12/presenter_delivery.jpg" src="https://da4w749qm6awt.cloudfront.net/engage-player/34758fd3-9896-4461-966a-7971e349fee3/attachment-12/presenter_delivery.jpg"/>
#         </div>
#         <div class="item-text">
#          <div class="publication-details item-element">
#           <!-- ngIf: showPubSeries -->
#           <div class="publication-title auto-launch" data-item-pub="pub" target="_blank" title="launch video for Effective Presentations. (CAPTIONS)">
#            Effective Presentations. (CAPTIONS)
#            <!-- ngIf: pub.pubLabel -->
#           </div>
#           <div class="pub-date ng-binding" data-date-time="13 Nov 2:30AM">
#            Fri, 13 Nov, 2:30AM
#           </div>
#           <div class="item-details ng-binding" data-ng-bind-html="pub.notes">
#           </div>
#           <span class="hideMe" data-ng-attr-class="{{!iAmAdmin &amp;&amp; 'hideMe' || 'displayMe' }}">
#            L21
#           </span>
#           <!-- ngRepeat: link in pub.links -->
#           <div class="publication-link type-L21" data-ng-repeat="link in pub.links ">
#            <a class="item-link " data-is-default-link="true" href="https://matterhorn.dce.harvard.edu/engage/player/watch.html?id=34758fd3-9896-4461-966a-7971e349fee3" target="_blank">
#             <!-- ngIf: link.liveStart -->
#            </a>
#           </div>
#           <!-- end ngRepeat: link in pub.links -->
#          </div>
#         </div>
#        </div>
#        <!-- end ngRepeat: pub in filteredPubs = (pubData.publications | orderBy:['-isLive', orderProp, '-dcType'] | pubLinkFilter:servertime | filter:query ) -->
#        <div class="item ng-scope" data-ng-repeat="pub in filteredPubs = (pubData.publications | orderBy:['-isLive', orderProp, '-dcType'] | pubLinkFilter:servertime | filter:query )" data-pub-item="data-pub-item">
#         <div class="item-element item-img auto-launch" target="_blank" title="launch video for Lecture 21">
#          <img alt="Snap shot of Lecture 21" class="thumb" data-item-pub="pub" data-ng-src="https://da4w749qm6awt.cloudfront.net/engage-player/d213b305-65a8-4ee8-95d3-4dfc4a437205/attachment-12/presenter_delivery.jpg" src="https://da4w749qm6awt.cloudfront.net/engage-player/d213b305-65a8-4ee8-95d3-4dfc4a437205/attachment-12/presenter_delivery.jpg"/>
#         </div>
#         <div class="item-text">
#          <div class="publication-details item-element">
#           <!-- ngIf: showPubSeries -->
#           <div class="publication-title auto-launch" data-item-pub="pub" target="_blank" title="launch video for Lecture 21">
#            Lecture 21
#            <!-- ngIf: pub.pubLabel -->
#           </div>
#           <div class="pub-date ng-binding" data-date-time="13 Nov 2:29AM">
#            Fri, 13 Nov, 2:29AM
#           </div>
#           <div class="item-details ng-binding" data-ng-bind-html="pub.notes">
#            Effective Presentations.
#           </div>
#           <span class="hideMe" data-ng-attr-class="{{!iAmAdmin &amp;&amp; 'hideMe' || 'displayMe' }}">
#            L21
#           </span>
#           <!-- ngRepeat: link in pub.links -->
#           <div class="publication-link type-L21" data-ng-repeat="link in pub.links ">
#            <a class="item-link " data-is-default-link="true" href="https://matterhorn.dce.harvard.edu/engage/player/watch.html?id=d213b305-65a8-4ee8-95d3-4dfc4a437205" target="_blank">
#             <!-- ngIf: link.liveStart -->
#            </a>
#           </div>
#           <!-- end ngRepeat: link in pub.links -->
#          </div>
#         </div>
#        </div>
#        <!-- end ngRepeat: pub in filteredPubs = (pubData.publications | orderBy:['-isLive', orderProp, '-dcType'] | pubLinkFilter:servertime | filter:query ) -->
#        <div class="item ng-scope" data-ng-repeat="pub in filteredPubs = (pubData.publications | orderBy:['-isLive', orderProp, '-dcType'] | pubLinkFilter:servertime | filter:query )" data-pub-item="data-pub-item">
#         <div class="item-element item-img auto-launch" target="_blank" title="launch video for Section 10 (CAPTIONS)">
#          <img alt="Snap shot of Section 10 (CAPTIONS)" class="thumb" data-item-pub="pub" data-ng-src="https://da4w749qm6awt.cloudfront.net/engage-player/b1d70f08-4c37-4ca7-9fd1-769f4a5adbd2/attachment-12/presenter_delivery.jpg" src="https://da4w749qm6awt.cloudfront.net/engage-player/b1d70f08-4c37-4ca7-9fd1-769f4a5adbd2/attachment-12/presenter_delivery.jpg"/>
#         </div>
#         <div class="item-text">
#          <div class="publication-details item-element">
#           <!-- ngIf: showPubSeries -->
#           <div class="publication-title auto-launch" data-item-pub="pub" target="_blank" title="launch video for Section 10 (CAPTIONS)">
#            Section 10 (CAPTIONS)
#            <!-- ngIf: pub.pubLabel -->
#           </div>
#           <div class="pub-date ng-binding" data-date-time="13 Nov 1:00AM">
#            Fri, 13 Nov, 1:00AM
#           </div>
#           <div class="item-details ng-binding" data-ng-bind-html="pub.notes">
#           </div>
#           <span class="hideMe" data-ng-attr-class="{{!iAmAdmin &amp;&amp; 'hideMe' || 'displayMe' }}">
#            S10
#           </span>
#           <!-- ngRepeat: link in pub.links -->
#           <div class="publication-link type-S10" data-ng-repeat="link in pub.links ">
#            <a class="item-link " data-is-default-link="true" href="https://matterhorn.dce.harvard.edu/engage/player/watch.html?id=b1d70f08-4c37-4ca7-9fd1-769f4a5adbd2" target="_blank">
#             <!-- ngIf: link.liveStart -->
#            </a>
#           </div>
#           <!-- end ngRepeat: link in pub.links -->
#          </div>
#         </div>
#        </div>
#        <!-- end ngRepeat: pub in filteredPubs = (pubData.publications | orderBy:['-isLive', orderProp, '-dcType'] | pubLinkFilter:servertime | filter:query ) -->
#        <div class="item ng-scope" data-ng-repeat="pub in filteredPubs = (pubData.publications | orderBy:['-isLive', orderProp, '-dcType'] | pubLinkFilter:servertime | filter:query )" data-pub-item="data-pub-item">
#         <div class="item-element item-img auto-launch" target="_blank" title="launch video for Section 10">
#          <img alt="Snap shot of Section 10" class="thumb" data-item-pub="pub" data-ng-src="https://da4w749qm6awt.cloudfront.net/engage-player/534829b6-1773-4e1d-b25d-aa2a2fbd2b95/attachment-12/presenter_delivery.jpg" src="https://da4w749qm6awt.cloudfront.net/engage-player/534829b6-1773-4e1d-b25d-aa2a2fbd2b95/attachment-12/presenter_delivery.jpg"/>
#         </div>
#         <div class="item-text">
#          <div class="publication-details item-element">
#           <!-- ngIf: showPubSeries -->
#           <div class="publication-title auto-launch" data-item-pub="pub" target="_blank" title="launch video for Section 10">
#            Section 10
#            <!-- ngIf: pub.pubLabel -->
#           </div>
#           <div class="pub-date ng-binding" data-date-time="13 Nov 12:59AM">
#            Fri, 13 Nov, 12:59AM
#           </div>
#           <div class="item-details ng-binding" data-ng-bind-html="pub.notes">
#           </div>
#           <span class="hideMe" data-ng-attr-class="{{!iAmAdmin &amp;&amp; 'hideMe' || 'displayMe' }}">
#            S10
#           </span>
#           <!-- ngRepeat: link in pub.links -->
#           <div class="publication-link type-S10" data-ng-repeat="link in pub.links ">
#            <a class="item-link " data-is-default-link="true" href="https://matterhorn.dce.harvard.edu/engage/player/watch.html?id=534829b6-1773-4e1d-b25d-aa2a2fbd2b95" target="_blank">
#             <!-- ngIf: link.liveStart -->
#            </a>
#           </div>
#           <!-- end ngRepeat: link in pub.links -->
#          </div>
#         </div>
#        </div>
#        <!-- end ngRepeat: pub in filteredPubs = (pubData.publications | orderBy:['-isLive', orderProp, '-dcType'] | pubLinkFilter:servertime | filter:query ) -->
#        <div class="item ng-scope" data-ng-repeat="pub in filteredPubs = (pubData.publications | orderBy:['-isLive', orderProp, '-dcType'] | pubLinkFilter:servertime | filter:query )" data-pub-item="data-pub-item">
#         <div class="item-element item-img auto-launch" target="_blank" title="launch video for Clustering. k-means. Mean Shift. Hierarchical Clustering.  (CAPTIONS)">
#          <img alt="Snap shot of Clustering. k-means. Mean Shift. Hierarchical Clustering.  (CAPTIONS)" class="thumb" data-item-pub="pub" data-ng-src="https://da4w749qm6awt.cloudfront.net/engage-player/03277e71-f8f1-443b-b13a-7e54f762b287/attachment-12/presenter_delivery.jpg" src="https://da4w749qm6awt.cloudfront.net/engage-player/03277e71-f8f1-443b-b13a-7e54f762b287/attachment-12/presenter_delivery.jpg"/>
#         </div>
#         <div class="item-text">
#          <div class="publication-details item-element">
#           <!-- ngIf: showPubSeries -->
#           <div class="publication-title auto-launch" data-item-pub="pub" target="_blank" title="launch video for Clustering. k-means. Mean Shift. Hierarchical Clustering.  (CAPTIONS)">
#            Clustering. k-means. Mean Shift. Hierarchical Clustering.  (CAPTIONS)
#            <!-- ngIf: pub.pubLabel -->
#           </div>
#           <div class="pub-date ng-binding" data-date-time="11 Nov 2:30AM">
#            Wed, 11 Nov, 2:30AM
#           </div>
#           <div class="item-details ng-binding" data-ng-bind-html="pub.notes">
#           </div>
#           <span class="hideMe" data-ng-attr-class="{{!iAmAdmin &amp;&amp; 'hideMe' || 'displayMe' }}">
#            L20
#           </span>
#           <!-- ngRepeat: link in pub.links -->
#           <div class="publication-link type-L20" data-ng-repeat="link in pub.links ">
#            <a class="item-link " data-is-default-link="true" href="https://matterhorn.dce.harvard.edu/engage/player/watch.html?id=03277e71-f8f1-443b-b13a-7e54f762b287" target="_blank">
#             <!-- ngIf: link.liveStart -->
#            </a>
#           </div>
#           <!-- end ngRepeat: link in pub.links -->
#          </div>
#         </div>
#        </div>
#        <!-- end ngRepeat: pub in filteredPubs = (pubData.publications | orderBy:['-isLive', orderProp, '-dcType'] | pubLinkFilter:servertime | filter:query ) -->
#        <div class="item ng-scope" data-ng-repeat="pub in filteredPubs = (pubData.publications | orderBy:['-isLive', orderProp, '-dcType'] | pubLinkFilter:servertime | filter:query )" data-pub-item="data-pub-item">
#         <div class="item-element item-img auto-launch" target="_blank" title="launch video for Lecture 20">
#          <img alt="Snap shot of Lecture 20" class="thumb" data-item-pub="pub" data-ng-src="https://da4w749qm6awt.cloudfront.net/engage-player/27aebc37-3c53-4ce8-a7cb-b2be397aa2f0/attachment-12/presenter_delivery.jpg" src="https://da4w749qm6awt.cloudfront.net/engage-player/27aebc37-3c53-4ce8-a7cb-b2be397aa2f0/attachment-12/presenter_delivery.jpg"/>
#         </div>
#         <div class="item-text">
#          <div class="publication-details item-element">
#           <!-- ngIf: showPubSeries -->
#           <div class="publication-title auto-launch" data-item-pub="pub" target="_blank" title="launch video for Lecture 20">
#            Lecture 20
#            <!-- ngIf: pub.pubLabel -->
#           </div>
#           <div class="pub-date ng-binding" data-date-time="11 Nov 2:29AM">
#            Wed, 11 Nov, 2:29AM
#           </div>
#           <div class="item-details ng-binding" data-ng-bind-html="pub.notes">
#            Clustering. k-means. Mean Shift. Hierarchical Clustering.
#           </div>
#           <span class="hideMe" data-ng-attr-class="{{!iAmAdmin &amp;&amp; 'hideMe' || 'displayMe' }}">
#            L20
#           </span>
#           <!-- ngRepeat: link in pub.links -->
#           <div class="publication-link type-L20" data-ng-repeat="link in pub.links ">
#            <a class="item-link " data-is-default-link="true" href="https://matterhorn.dce.harvard.edu/engage/player/watch.html?id=27aebc37-3c53-4ce8-a7cb-b2be397aa2f0" target="_blank">
#             <!-- ngIf: link.liveStart -->
#            </a>
#           </div>
#           <!-- end ngRepeat: link in pub.links -->
#          </div>
#         </div>
#        </div>
#        <!-- end ngRepeat: pub in filteredPubs = (pubData.publications | orderBy:['-isLive', orderProp, '-dcType'] | pubLinkFilter:servertime | filter:query ) -->
#        <div class="item ng-scope" data-ng-repeat="pub in filteredPubs = (pubData.publications | orderBy:['-isLive', orderProp, '-dcType'] | pubLinkFilter:servertime | filter:query )" data-pub-item="data-pub-item">
#         <div class="item-element item-img auto-launch" target="_blank" title="launch video for Interactive Visualizations. Tableau. (CAPTIONS)">
#          <img alt="Snap shot of Interactive Visualizations. Tableau. (CAPTIONS)" class="thumb" data-item-pub="pub" data-ng-src="https://da4w749qm6awt.cloudfront.net/engage-player/5ca8d569-0c51-47aa-83df-147cc4b97e57/attachment-12/presenter_delivery.jpg" src="https://da4w749qm6awt.cloudfront.net/engage-player/5ca8d569-0c51-47aa-83df-147cc4b97e57/attachment-12/presenter_delivery.jpg"/>
#         </div>
#         <div class="item-text">
#          <div class="publication-details item-element">
#           <!-- ngIf: showPubSeries -->
#           <div class="publication-title auto-launch" data-item-pub="pub" target="_blank" title="launch video for Interactive Visualizations. Tableau. (CAPTIONS)">
#            Interactive Visualizations. Tableau. (CAPTIONS)
#            <!-- ngIf: pub.pubLabel -->
#           </div>
#           <div class="pub-date ng-binding" data-date-time="06 Nov 2:30AM">
#            Fri, 06 Nov, 2:30AM
#           </div>
#           <div class="item-details ng-binding" data-ng-bind-html="pub.notes">
#           </div>
#           <span class="hideMe" data-ng-attr-class="{{!iAmAdmin &amp;&amp; 'hideMe' || 'displayMe' }}">
#            L19
#           </span>
#           <!-- ngRepeat: link in pub.links -->
#           <div class="publication-link type-L19" data-ng-repeat="link in pub.links ">
#            <a class="item-link " data-is-default-link="true" href="https://matterhorn.dce.harvard.edu/engage/player/watch.html?id=5ca8d569-0c51-47aa-83df-147cc4b97e57" target="_blank">
#             <!-- ngIf: link.liveStart -->
#            </a>
#           </div>
#           <!-- end ngRepeat: link in pub.links -->
#          </div>
#         </div>
#        </div>
#        <!-- end ngRepeat: pub in filteredPubs = (pubData.publications | orderBy:['-isLive', orderProp, '-dcType'] | pubLinkFilter:servertime | filter:query ) -->
#        <div class="item ng-scope" data-ng-repeat="pub in filteredPubs = (pubData.publications | orderBy:['-isLive', orderProp, '-dcType'] | pubLinkFilter:servertime | filter:query )" data-pub-item="data-pub-item">
#         <div class="item-element item-img auto-launch" target="_blank" title="launch video for Lecture 19">
#          <img alt="Snap shot of Lecture 19" class="thumb" data-item-pub="pub" data-ng-src="https://da4w749qm6awt.cloudfront.net/engage-player/51e980dd-56a4-4b44-aec5-516ed9c53a2c/attachment-12/presenter_delivery.jpg" src="https://da4w749qm6awt.cloudfront.net/engage-player/51e980dd-56a4-4b44-aec5-516ed9c53a2c/attachment-12/presenter_delivery.jpg"/>
#         </div>
#         <div class="item-text">
#          <div class="publication-details item-element">
#           <!-- ngIf: showPubSeries -->
#           <div class="publication-title auto-launch" data-item-pub="pub" target="_blank" title="launch video for Lecture 19">
#            Lecture 19
#            <!-- ngIf: pub.pubLabel -->
#           </div>
#           <div class="pub-date ng-binding" data-date-time="06 Nov 2:29AM">
#            Fri, 06 Nov, 2:29AM
#           </div>
#           <div class="item-details ng-binding" data-ng-bind-html="pub.notes">
#            Interactive Visualizations. Tableau.
#           </div>
#           <span class="hideMe" data-ng-attr-class="{{!iAmAdmin &amp;&amp; 'hideMe' || 'displayMe' }}">
#            L19
#           </span>
#           <!-- ngRepeat: link in pub.links -->
#           <div class="publication-link type-L19" data-ng-repeat="link in pub.links ">
#            <a class="item-link " data-is-default-link="true" href="https://matterhorn.dce.harvard.edu/engage/player/watch.html?id=51e980dd-56a4-4b44-aec5-516ed9c53a2c" target="_blank">
#             <!-- ngIf: link.liveStart -->
#            </a>
#           </div>
#           <!-- end ngRepeat: link in pub.links -->
#          </div>
#         </div>
#        </div>
#        <!-- end ngRepeat: pub in filteredPubs = (pubData.publications | orderBy:['-isLive', orderProp, '-dcType'] | pubLinkFilter:servertime | filter:query ) -->
#        <div class="item ng-scope" data-ng-repeat="pub in filteredPubs = (pubData.publications | orderBy:['-isLive', orderProp, '-dcType'] | pubLinkFilter:servertime | filter:query )" data-pub-item="data-pub-item">
#         <div class="item-element item-img auto-launch" target="_blank" title="launch video for Section 9 (CAPTIONS)">
#          <img alt="Snap shot of Section 9 (CAPTIONS)" class="thumb" data-item-pub="pub" data-ng-src="https://da4w749qm6awt.cloudfront.net/engage-player/3c49a6e1-b9e6-470a-9605-0478f8ec382b/attachment-12/presenter_delivery.jpg" src="https://da4w749qm6awt.cloudfront.net/engage-player/3c49a6e1-b9e6-470a-9605-0478f8ec382b/attachment-12/presenter_delivery.jpg"/>
#         </div>
#         <div class="item-text">
#          <div class="publication-details item-element">
#           <!-- ngIf: showPubSeries -->
#           <div class="publication-title auto-launch" data-item-pub="pub" target="_blank" title="launch video for Section 9 (CAPTIONS)">
#            Section 9 (CAPTIONS)
#            <!-- ngIf: pub.pubLabel -->
#           </div>
#           <div class="pub-date ng-binding" data-date-time="06 Nov 1:00AM">
#            Fri, 06 Nov, 1:00AM
#           </div>
#           <div class="item-details ng-binding" data-ng-bind-html="pub.notes">
#           </div>
#           <span class="hideMe" data-ng-attr-class="{{!iAmAdmin &amp;&amp; 'hideMe' || 'displayMe' }}">
#            S09
#           </span>
#           <!-- ngRepeat: link in pub.links -->
#           <div class="publication-link type-S09" data-ng-repeat="link in pub.links ">
#            <a class="item-link " data-is-default-link="true" href="https://matterhorn.dce.harvard.edu/engage/player/watch.html?id=3c49a6e1-b9e6-470a-9605-0478f8ec382b" target="_blank">
#             <!-- ngIf: link.liveStart -->
#            </a>
#           </div>
#           <!-- end ngRepeat: link in pub.links -->
#          </div>
#         </div>
#        </div>
#        <!-- end ngRepeat: pub in filteredPubs = (pubData.publications | orderBy:['-isLive', orderProp, '-dcType'] | pubLinkFilter:servertime | filter:query ) -->
#        <div class="item ng-scope" data-ng-repeat="pub in filteredPubs = (pubData.publications | orderBy:['-isLive', orderProp, '-dcType'] | pubLinkFilter:servertime | filter:query )" data-pub-item="data-pub-item">
#         <div class="item-element item-img auto-launch" target="_blank" title="launch video for Section 9">
#          <img alt="Snap shot of Section 9" class="thumb" data-item-pub="pub" data-ng-src="https://da4w749qm6awt.cloudfront.net/engage-player/52e74ae5-f08b-4bf8-b0a2-b0eeae127856/attachment-12/presenter_delivery.jpg" src="https://da4w749qm6awt.cloudfront.net/engage-player/52e74ae5-f08b-4bf8-b0a2-b0eeae127856/attachment-12/presenter_delivery.jpg"/>
#         </div>
#         <div class="item-text">
#          <div class="publication-details item-element">
#           <!-- ngIf: showPubSeries -->
#           <div class="publication-title auto-launch" data-item-pub="pub" target="_blank" title="launch video for Section 9">
#            Section 9
#            <!-- ngIf: pub.pubLabel -->
#           </div>
#           <div class="pub-date ng-binding" data-date-time="06 Nov 12:59AM">
#            Fri, 06 Nov, 12:59AM
#           </div>
#           <div class="item-details ng-binding" data-ng-bind-html="pub.notes">
#           </div>
#           <span class="hideMe" data-ng-attr-class="{{!iAmAdmin &amp;&amp; 'hideMe' || 'displayMe' }}">
#            S09
#           </span>
#           <!-- ngRepeat: link in pub.links -->
#           <div class="publication-link type-S09" data-ng-repeat="link in pub.links ">
#            <a class="item-link " data-is-default-link="true" href="https://matterhorn.dce.harvard.edu/engage/player/watch.html?id=52e74ae5-f08b-4bf8-b0a2-b0eeae127856" target="_blank">
#             <!-- ngIf: link.liveStart -->
#            </a>
#           </div>
#           <!-- end ngRepeat: link in pub.links -->
#          </div>
#         </div>
#        </div>
#        <!-- end ngRepeat: pub in filteredPubs = (pubData.publications | orderBy:['-isLive', orderProp, '-dcType'] | pubLinkFilter:servertime | filter:query ) -->
#        <div class="item ng-scope" data-ng-repeat="pub in filteredPubs = (pubData.publications | orderBy:['-isLive', orderProp, '-dcType'] | pubLinkFilter:servertime | filter:query )" data-pub-item="data-pub-item">
#         <div class="item-element item-img auto-launch" target="_blank" title="launch video for Text Analysis. LDA. Topic Modeling. (CAPTIONS)">
#          <img alt="Snap shot of Text Analysis. LDA. Topic Modeling. (CAPTIONS)" class="thumb" data-item-pub="pub" data-ng-src="https://da4w749qm6awt.cloudfront.net/engage-player/432bb538-45a0-41d3-bb4e-f7b81b0fe811/attachment-12/presenter_delivery.jpg" src="https://da4w749qm6awt.cloudfront.net/engage-player/432bb538-45a0-41d3-bb4e-f7b81b0fe811/attachment-12/presenter_delivery.jpg"/>
#         </div>
#         <div class="item-text">
#          <div class="publication-details item-element">
#           <!-- ngIf: showPubSeries -->
#           <div class="publication-title auto-launch" data-item-pub="pub" target="_blank" title="launch video for Text Analysis. LDA. Topic Modeling. (CAPTIONS)">
#            Text Analysis. LDA. Topic Modeling. (CAPTIONS)
#            <!-- ngIf: pub.pubLabel -->
#           </div>
#           <div class="pub-date ng-binding" data-date-time="04 Nov 2:30AM">
#            Wed, 04 Nov, 2:30AM
#           </div>
#           <div class="item-details ng-binding" data-ng-bind-html="pub.notes">
#           </div>
#           <span class="hideMe" data-ng-attr-class="{{!iAmAdmin &amp;&amp; 'hideMe' || 'displayMe' }}">
#            L18
#           </span>
#           <!-- ngRepeat: link in pub.links -->
#           <div class="publication-link type-L18" data-ng-repeat="link in pub.links ">
#            <a class="item-link " data-is-default-link="true" href="https://matterhorn.dce.harvard.edu/engage/player/watch.html?id=432bb538-45a0-41d3-bb4e-f7b81b0fe811" target="_blank">
#             <!-- ngIf: link.liveStart -->
#            </a>
#           </div>
#           <!-- end ngRepeat: link in pub.links -->
#          </div>
#         </div>
#        </div>
#        <!-- end ngRepeat: pub in filteredPubs = (pubData.publications | orderBy:['-isLive', orderProp, '-dcType'] | pubLinkFilter:servertime | filter:query ) -->
#        <div class="item ng-scope" data-ng-repeat="pub in filteredPubs = (pubData.publications | orderBy:['-isLive', orderProp, '-dcType'] | pubLinkFilter:servertime | filter:query )" data-pub-item="data-pub-item">
#         <div class="item-element item-img auto-launch" target="_blank" title="launch video for Lecture 18">
#          <img alt="Snap shot of Lecture 18" class="thumb" data-item-pub="pub" data-ng-src="https://da4w749qm6awt.cloudfront.net/engage-player/8b18c591-27e0-4ea9-8834-8bab321b166a/attachment-12/presenter_delivery.jpg" src="https://da4w749qm6awt.cloudfront.net/engage-player/8b18c591-27e0-4ea9-8834-8bab321b166a/attachment-12/presenter_delivery.jpg"/>
#         </div>
#         <div class="item-text">
#          <div class="publication-details item-element">
#           <!-- ngIf: showPubSeries -->
#           <div class="publication-title auto-launch" data-item-pub="pub" target="_blank" title="launch video for Lecture 18">
#            Lecture 18
#            <!-- ngIf: pub.pubLabel -->
#           </div>
#           <div class="pub-date ng-binding" data-date-time="04 Nov 2:29AM">
#            Wed, 04 Nov, 2:29AM
#           </div>
#           <div class="item-details ng-binding" data-ng-bind-html="pub.notes">
#            Text Analysis. LDA. Topic Modeling
#           </div>
#           <span class="hideMe" data-ng-attr-class="{{!iAmAdmin &amp;&amp; 'hideMe' || 'displayMe' }}">
#            L18
#           </span>
#           <!-- ngRepeat: link in pub.links -->
#           <div class="publication-link type-L18" data-ng-repeat="link in pub.links ">
#            <a class="item-link " data-is-default-link="true" href="https://matterhorn.dce.harvard.edu/engage/player/watch.html?id=8b18c591-27e0-4ea9-8834-8bab321b166a" target="_blank">
#             <!-- ngIf: link.liveStart -->
#            </a>
#           </div>
#           <!-- end ngRepeat: link in pub.links -->
#          </div>
#         </div>
#        </div>
#        <!-- end ngRepeat: pub in filteredPubs = (pubData.publications | orderBy:['-isLive', orderProp, '-dcType'] | pubLinkFilter:servertime | filter:query ) -->
#        <div class="item ng-scope" data-ng-repeat="pub in filteredPubs = (pubData.publications | orderBy:['-isLive', orderProp, '-dcType'] | pubLinkFilter:servertime | filter:query )" data-pub-item="data-pub-item">
#         <div class="item-element item-img auto-launch" target="_blank" title="launch video for Section 8, extra session (CAPTIONS)">
# ...
#             <!-- ngIf: link.liveStart -->
#            </a>
#           </div>
#           <!-- end ngRepeat: link in pub.links -->
#          </div>
#         </div>
#        </div>
#        <!-- end ngRepeat: pub in filteredPubs = (pubData.publications | orderBy:['-isLive', orderProp, '-dcType'] | pubLinkFilter:servertime | filter:query ) -->
#        <div class="item ng-scope" data-ng-repeat="pub in filteredPubs = (pubData.publications | orderBy:['-isLive', orderProp, '-dcType'] | pubLinkFilter:servertime | filter:query )" data-pub-item="data-pub-item">
#         <div class="item-element item-img auto-launch" target="_blank" title="launch video for Exploratory Data Analysis. Effective Visualizations. (CAPTIONS)">
#          <img alt="Snap shot of Exploratory Data Analysis. Effective Visualizations. (CAPTIONS)" class="thumb" data-item-pub="pub" data-ng-src="https://da4w749qm6awt.cloudfront.net/engage-player/4dc7719e-1ef4-4ee5-a9d9-fc48c3e13185/attachment-9/presenter_delivery.jpg" src="https://da4w749qm6awt.cloudfront.net/engage-player/4dc7719e-1ef4-4ee5-a9d9-fc48c3e13185/attachment-9/presenter_delivery.jpg"/>
#         </div>
#         <div class="item-text">
#          <div class="publication-details item-element">
#           <!-- ngIf: showPubSeries -->
#           <div class="publication-title auto-launch" data-item-pub="pub" target="_blank" title="launch video for Exploratory Data Analysis. Effective Visualizations. (CAPTIONS)">
#            Exploratory Data Analysis. Effective Visualizations. (CAPTIONS)
#            <!-- ngIf: pub.pubLabel -->
#           </div>
#           <div class="pub-date ng-binding" data-date-time="15 Sep 1:30AM">
#            Tue, 15 Sep, 1:30AM
#           </div>
#           <div class="item-details ng-binding" data-ng-bind-html="pub.notes">
#           </div>
#           <span class="hideMe" data-ng-attr-class="{{!iAmAdmin &amp;&amp; 'hideMe' || 'displayMe' }}">
#            L03
#           </span>
#           <!-- ngRepeat: link in pub.links -->
#           <div class="publication-link type-L03" data-ng-repeat="link in pub.links ">
#            <a class="item-link " data-is-default-link="true" href="https://matterhorn.dce.harvard.edu/engage/player/watch.html?id=4dc7719e-1ef4-4ee5-a9d9-fc48c3e13185" target="_blank">
#             <!-- ngIf: link.liveStart -->
#            </a>
#           </div>
#           <!-- end ngRepeat: link in pub.links -->
#          </div>
#         </div>
#        </div>
#        <!-- end ngRepeat: pub in filteredPubs = (pubData.publications | orderBy:['-isLive', orderProp, '-dcType'] | pubLinkFilter:servertime | filter:query ) -->
#        <div class="item ng-scope" data-ng-repeat="pub in filteredPubs = (pubData.publications | orderBy:['-isLive', orderProp, '-dcType'] | pubLinkFilter:servertime | filter:query )" data-pub-item="data-pub-item">
#         <div class="item-element item-img auto-launch" target="_blank" title="launch video for Exploratory Data Analysis. Effective Visualizations.">
#          <img alt="Snap shot of Exploratory Data Analysis. Effective Visualizations." class="thumb" data-item-pub="pub" data-ng-src="https://da4w749qm6awt.cloudfront.net/engage-player/a4e81697-fd86-415c-9b29-c14ea7ec15f2/attachment-9/presenter_delivery.jpg" src="https://da4w749qm6awt.cloudfront.net/engage-player/a4e81697-fd86-415c-9b29-c14ea7ec15f2/attachment-9/presenter_delivery.jpg"/>
#         </div>
#         <div class="item-text">
#          <div class="publication-details item-element">
#           <!-- ngIf: showPubSeries -->
#           <div class="publication-title auto-launch" data-item-pub="pub" target="_blank" title="launch video for Exploratory Data Analysis. Effective Visualizations.">
#            Exploratory Data Analysis. Effective Visualizations.
#            <!-- ngIf: pub.pubLabel -->
#           </div>
#           <div class="pub-date ng-binding" data-date-time="11 Sep 1:30AM">
#            Fri, 11 Sep, 1:30AM
#           </div>
#           <div class="item-details ng-binding" data-ng-bind-html="pub.notes">
#           </div>
#           <span class="hideMe" data-ng-attr-class="{{!iAmAdmin &amp;&amp; 'hideMe' || 'displayMe' }}">
#            L03
#           </span>
#           <!-- ngRepeat: link in pub.links -->
#           <div class="publication-link type-L03" data-ng-repeat="link in pub.links ">
#            <a class="item-link " data-is-default-link="true" href="https://matterhorn.dce.harvard.edu/engage/player/watch.html?id=a4e81697-fd86-415c-9b29-c14ea7ec15f2" target="_blank">
#             <!-- ngIf: link.liveStart -->
#            </a>
#           </div>
#           <!-- end ngRepeat: link in pub.links -->
#          </div>
#         </div>
#        </div>
#        <!-- end ngRepeat: pub in filteredPubs = (pubData.publications | orderBy:['-isLive', orderProp, '-dcType'] | pubLinkFilter:servertime | filter:query ) -->
#        <div class="item ng-scope" data-ng-repeat="pub in filteredPubs = (pubData.publications | orderBy:['-isLive', orderProp, '-dcType'] | pubLinkFilter:servertime | filter:query )" data-pub-item="data-pub-item">
#         <div class="item-element item-img auto-launch" target="_blank" title="launch video for Section 1 (CAPTIONS)">
#          <img alt="Snap shot of Section 1 (CAPTIONS)" class="thumb" data-item-pub="pub" data-ng-src="https://da4w749qm6awt.cloudfront.net/engage-player/62b95e14-c296-44da-9691-446dfa313836/attachment-8/presenter_delivery.jpg" src="https://da4w749qm6awt.cloudfront.net/engage-player/62b95e14-c296-44da-9691-446dfa313836/attachment-8/presenter_delivery.jpg"/>
#         </div>
#         <div class="item-text">
#          <div class="publication-details item-element">
#           <!-- ngIf: showPubSeries -->
#           <div class="publication-title auto-launch" data-item-pub="pub" target="_blank" title="launch video for Section 1 (CAPTIONS)">
#            Section 1 (CAPTIONS)
#            <!-- ngIf: pub.pubLabel -->
#           </div>
#           <div class="pub-date ng-binding" data-date-time="11 Sep 12:00AM">
#            Fri, 11 Sep, 12:00AM
#           </div>
#           <div class="item-details ng-binding" data-ng-bind-html="pub.notes">
#           </div>
#           <span class="hideMe" data-ng-attr-class="{{!iAmAdmin &amp;&amp; 'hideMe' || 'displayMe' }}">
#            S01
#           </span>
#           <!-- ngRepeat: link in pub.links -->
#           <div class="publication-link type-S01" data-ng-repeat="link in pub.links ">
#            <a class="item-link " data-is-default-link="true" href="https://matterhorn.dce.harvard.edu/engage/player/watch.html?id=62b95e14-c296-44da-9691-446dfa313836" target="_blank">
#             <!-- ngIf: link.liveStart -->
#            </a>
#           </div>
#           <!-- end ngRepeat: link in pub.links -->
#          </div>
#         </div>
#        </div>
#        <!-- end ngRepeat: pub in filteredPubs = (pubData.publications | orderBy:['-isLive', orderProp, '-dcType'] | pubLinkFilter:servertime | filter:query ) -->
#        <div class="item ng-scope" data-ng-repeat="pub in filteredPubs = (pubData.publications | orderBy:['-isLive', orderProp, '-dcType'] | pubLinkFilter:servertime | filter:query )" data-pub-item="data-pub-item">
#         <div class="item-element item-img auto-launch" target="_blank" title="launch video for Section 1">
#          <img alt="Snap shot of Section 1" class="thumb" data-item-pub="pub" data-ng-src="https://da4w749qm6awt.cloudfront.net/engage-player/b89de485-9e30-4783-9287-23701c5f95f7/attachment-9/presenter_delivery.jpg" src="https://da4w749qm6awt.cloudfront.net/engage-player/b89de485-9e30-4783-9287-23701c5f95f7/attachment-9/presenter_delivery.jpg"/>
#         </div>
#         <div class="item-text">
#          <div class="publication-details item-element">
#           <!-- ngIf: showPubSeries -->
#           <div class="publication-title auto-launch" data-item-pub="pub" target="_blank" title="launch video for Section 1">
#            Section 1
#            <!-- ngIf: pub.pubLabel -->
#           </div>
#           <div class="pub-date ng-binding" data-date-time="10 Sep 11:59PM">
#            Thu, 10 Sep, 11:59PM
#           </div>
#           <div class="item-details ng-binding" data-ng-bind-html="pub.notes">
#           </div>
#           <span class="hideMe" data-ng-attr-class="{{!iAmAdmin &amp;&amp; 'hideMe' || 'displayMe' }}">
#            S01
#           </span>
#           <!-- ngRepeat: link in pub.links -->
#           <div class="publication-link type-S01" data-ng-repeat="link in pub.links ">
#            <a class="item-link " data-is-default-link="true" href="https://matterhorn.dce.harvard.edu/engage/player/watch.html?id=b89de485-9e30-4783-9287-23701c5f95f7" target="_blank">
#             <!-- ngIf: link.liveStart -->
#            </a>
#           </div>
#           <!-- end ngRepeat: link in pub.links -->
#          </div>
#         </div>
#        </div>
#        <!-- end ngRepeat: pub in filteredPubs = (pubData.publications | orderBy:['-isLive', orderProp, '-dcType'] | pubLinkFilter:servertime | filter:query ) -->
#        <div class="item ng-scope" data-ng-repeat="pub in filteredPubs = (pubData.publications | orderBy:['-isLive', orderProp, '-dcType'] | pubLinkFilter:servertime | filter:query )" data-pub-item="data-pub-item">
#         <div class="item-element item-img auto-launch" target="_blank" title="launch video for Web Scraping. Regular Expressions. Data Reshaping. Data Cleanup. Pandas">
#          <img alt="Snap shot of Web Scraping. Regular Expressions. Data Reshaping. Data Cleanup. Pandas" class="thumb" data-item-pub="pub" data-ng-src="https://da4w749qm6awt.cloudfront.net/engage-player/f7ff1893-fbf7-4909-b44e-12e61a98a677/attachment-9/presenter_delivery.jpg" src="https://da4w749qm6awt.cloudfront.net/engage-player/f7ff1893-fbf7-4909-b44e-12e61a98a677/attachment-9/presenter_delivery.jpg"/>
#         </div>
#         <div class="item-text">
#          <div class="publication-details item-element">
#           <!-- ngIf: showPubSeries -->
#           <div class="publication-title auto-launch" data-item-pub="pub" target="_blank" title="launch video for Web Scraping. Regular Expressions. Data Reshaping. Data Cleanup. Pandas">
#            Web Scraping. Regular Expressions. Data Reshaping. Data Cleanup. Pandas
#            <!-- ngIf: pub.pubLabel -->
#           </div>
#           <div class="pub-date ng-binding" data-date-time="09 Sep 1:30AM">
#            Wed, 09 Sep, 1:30AM
#           </div>
#           <div class="item-details ng-binding" data-ng-bind-html="pub.notes">
#           </div>
#           <span class="hideMe" data-ng-attr-class="{{!iAmAdmin &amp;&amp; 'hideMe' || 'displayMe' }}">
#            L02
#           </span>
#           <!-- ngRepeat: link in pub.links -->
#           <div class="publication-link type-L02" data-ng-repeat="link in pub.links ">
#            <a class="item-link " data-is-default-link="true" href="https://matterhorn.dce.harvard.edu/engage/player/watch.html?id=f7ff1893-fbf7-4909-b44e-12e61a98a677" target="_blank">
#             <!-- ngIf: link.liveStart -->
#            </a>
#           </div>
#           <!-- end ngRepeat: link in pub.links -->
#          </div>
#         </div>
#        </div>
#        <!-- end ngRepeat: pub in filteredPubs = (pubData.publications | orderBy:['-isLive', orderProp, '-dcType'] | pubLinkFilter:servertime | filter:query ) -->
#        <div class="item ng-scope" data-ng-repeat="pub in filteredPubs = (pubData.publications | orderBy:['-isLive', orderProp, '-dcType'] | pubLinkFilter:servertime | filter:query )" data-pub-item="data-pub-item">
#         <div class="item-element item-img auto-launch" target="_blank" title="launch video for First Week Collective Section (SD version has Captions)">
#          <img alt="Snap shot of First Week Collective Section (SD version has Captions)" class="thumb" data-item-pub="pub" data-ng-src="https://da4w749qm6awt.cloudfront.net/engage-player/e15f221c-5275-4f7f-b486-759a7d483bc8/attachment-9/presenter_delivery.jpg" src="https://da4w749qm6awt.cloudfront.net/engage-player/e15f221c-5275-4f7f-b486-759a7d483bc8/attachment-9/presenter_delivery.jpg"/>
#         </div>
#         <div class="item-text">
#          <div class="publication-details item-element">
#           <!-- ngIf: showPubSeries -->
#           <div class="publication-title auto-launch" data-item-pub="pub" target="_blank" title="launch video for First Week Collective Section (SD version has Captions)">
#            First Week Collective Section (SD version has Captions)
#            <!-- ngIf: pub.pubLabel -->
#           </div>
#           <div class="pub-date ng-binding" data-date-time="04 Sep 8:59PM">
#            Fri, 04 Sep, 8:59PM
#           </div>
#           <div class="item-details ng-binding" data-ng-bind-html="pub.notes">
#            First Week Collective Session
#           </div>
#           <span class="hideMe" data-ng-attr-class="{{!iAmAdmin &amp;&amp; 'hideMe' || 'displayMe' }}">
#            P01
#           </span>
#           <!-- ngRepeat: link in pub.links -->
#           <div class="publication-link type-P01" data-ng-repeat="link in pub.links ">
#            <a class="item-link " data-is-default-link="true" href="https://matterhorn.dce.harvard.edu/engage/player/watch.html?id=e15f221c-5275-4f7f-b486-759a7d483bc8" target="_blank">
#             <!-- ngIf: link.liveStart -->
#            </a>
#           </div>
#           <!-- end ngRepeat: link in pub.links -->
#          </div>
#         </div>
#        </div>
#        <!-- end ngRepeat: pub in filteredPubs = (pubData.publications | orderBy:['-isLive', orderProp, '-dcType'] | pubLinkFilter:servertime | filter:query ) -->
#       </div>
#       <span class="ng-binding" ng-bind="setNoPubMessage(filteredPubs.length)">
#       </span>
#      </div>
#     </div>
#     <!-- end ngIf: !pubMessage -->
#    </div>
#   </div>
#   <div data-ng-class="{'embedded':embedded || ltitool}" id="footer">
#    <div>
#     <div id="footer-privacy">
#      <a href="http://www.extension.harvard.edu/privacy-policy" title="Privacy policy">
#       Privacy Policy
#      </a>
#      |
#      <a href="#/tos" title="Terms of Use">
#       Terms of Use
#      </a>
#     </div>
#     <div id="footer-copyright">
#      Â©
#      <span id="copyright-year">
#       2017
#      </span>
#      President and Fellows of Harvard College
#     </div>
#    </div>
#   </div>
#   <!-- END #footer -->
#   <!--[if lt IE 7]>
#       <p class="browsehappy">You are using an <strong>outdated</strong> browser. Please <a href="http://browsehappy.com/">upgrade your browser</a> to improve your experience.</p>
#   <![endif]-->
#   <div data-app-version="app-version" style="display:none">
#    1.1.0
#   </div>
#   <script src="combined/bower_components/angular/angular.js">
#   </script>
#   <script src="combined/bower_components/angular-route/angular-route.js">
#   </script>
#   <script src="combined/bower_components/angular-resource/angular-resource.js">
#   </script>
#   <script src="combined/bower_components/angular-sanitize/angular-sanitize.js">
#   </script>
#   <script src="combined/bower_components/moment/moment.js">
#   </script>
#   <script src="combined/bower_components/moment-timezone/moment-timezone-with-data-2010-2020.js">
#   </script>
#   <script src="combined/app.js">
#   </script>
#   <script src="combined/views/seriesview/seriesview.js">
#   </script>
#   <script src="combined/views/publistview/publistview.js">
#   </script>
#   <script src="combined/components/version/version.js">
#   </script>
#   <script src="combined/components/version/version-directive.js">
#   </script>
#   <script src="combined/components/version/interpolate-filter.js">
#   </script>
#   <script src="combined/components/combojs/services.js" type="text/javascript">
#   </script>
#   <script src="combined/components/combojs/liveFilter.js" type="text/javascript">
#   </script>
#   <script src="combined/components/combojs/liveTimerDirective.js" type="text/javascript">
#   </script>
#   <script src="combined/components/combojs/refreshService.js" type="text/javascript">
#   </script>
#   <script src="combined/components/combojs/dataTransformService.js" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    var copyrightyear = document.getElementById('copyright-year');
#     if (copyrightyear) {
#       copyrightyear.innerHTML = new Date().getFullYear();
#     }
#   </script>
#  </body>
# </html>

# %%
# to remove file if it exists
import os
try: os.remove('list_add.txt')
except: pass

# write to file, manually remove unwanteds
with open('list_add.txt', 'a') as f:
    for line in zip(title_list, date_list, link_list):
        f.write(str(line))
        f.write('\n')

# %%
# import in the files you want to save.
with open('list_add(selected).txt', 'r') as f:
    wanted_list = []
    for line in f:
        if line[0] != '(':
            continue
        # catch wrong filenames
        if len(line[2:-3].split("', '")) != 3:
            print 'ERROR!', line
        c = line[2:-3].split("', '")
        wanted_list.append((c[0], c[1], c[2]))

index = 1
for n,d,w in wanted_list:
    print index, w
    index +=1
    
# manually go to the sites and save the html
# Out:
# 1 https://matterhorn.dce.harvard.edu/engage/player/watch.html?id=b721f1db-9c16-464b-bcd3-3d81e7cd13a1
# 2 https://matterhorn.dce.harvard.edu/engage/player/watch.html?id=32a2d292-50eb-44b0-9f28-a728e515d612
# 3 https://matterhorn.dce.harvard.edu/engage/player/watch.html?id=128b8123-a1a6-493c-bac7-a932234374a0
# 4 https://matterhorn.dce.harvard.edu/engage/player/watch.html?id=12bfea44-634f-4bc0-b88d-0aca05a3c289
# 5 https://matterhorn.dce.harvard.edu/engage/player/watch.html?id=94e52a8d-6557-48c4-b003-b5ec84d2a1e2
# 6 https://matterhorn.dce.harvard.edu/engage/player/watch.html?id=34758fd3-9896-4461-966a-7971e349fee3
# 7 https://matterhorn.dce.harvard.edu/engage/player/watch.html?id=b1d70f08-4c37-4ca7-9fd1-769f4a5adbd2
# 8 https://matterhorn.dce.harvard.edu/engage/player/watch.html?id=03277e71-f8f1-443b-b13a-7e54f762b287
# 9 https://matterhorn.dce.harvard.edu/engage/player/watch.html?id=5ca8d569-0c51-47aa-83df-147cc4b97e57
# 10 https://matterhorn.dce.harvard.edu/engage/player/watch.html?id=3c49a6e1-b9e6-470a-9605-0478f8ec382b
# 11 https://matterhorn.dce.harvard.edu/engage/player/watch.html?id=432bb538-45a0-41d3-bb4e-f7b81b0fe811
# 12 https://matterhorn.dce.harvard.edu/engage/player/watch.html?id=d0af29d8-67fc-4e87-8394-a0d266fde6c2
# 13 https://matterhorn.dce.harvard.edu/engage/player/watch.html?id=35282cbd-94b3-4fd7-bd5e-b3a8f40e72b1
# 14 https://matterhorn.dce.harvard.edu/engage/player/watch.html?id=7ab74365-fff6-4419-8bb5-7e0a31e4545c
# 15 https://matterhorn.dce.harvard.edu/engage/player/watch.html?id=15fcc277-f6f1-4db5-9b8b-f941c49db487
# 16 https://matterhorn.dce.harvard.edu/engage/player/watch.html?id=4d529afe-7fe0-42b8-a4d8-50aca797bdcf
# 17 https://matterhorn.dce.harvard.edu/engage/player/watch.html?id=6d41b545-6329-49e7-a2b8-ec0d218a5bc5
# 18 https://matterhorn.dce.harvard.edu/engage/player/watch.html?id=4199ca62-a007-4b08-b2e2-f752c2dcc01a
# 19 https://matterhorn.dce.harvard.edu/engage/player/watch.html?id=3d4f72cf-9de9-4d07-bc80-cd0f0ab6b82d
# 20 https://matterhorn.dce.harvard.edu/engage/player/watch.html?id=3dfcfa72-4dad-47fd-b0d7-b72867a3ec87
# 21 https://matterhorn.dce.harvard.edu/engage/player/watch.html?id=6f374ba5-6e54-432c-9916-fb61fa2327ef
# 22 https://matterhorn.dce.harvard.edu/engage/player/watch.html?id=2a006499-49a7-4e2e-b5d8-bfa7a9510132
# 23 https://matterhorn.dce.harvard.edu/engage/player/watch.html?id=c22cbde8-94dd-42ad-86ef-091448ad02e4
# 24 https://matterhorn.dce.harvard.edu/engage/player/watch.html?id=8ce7995a-c374-4946-b01f-c8d7b0d2614b
# 25 https://matterhorn.dce.harvard.edu/engage/player/watch.html?id=92e3adbf-2212-4cff-b1a9-b1bfe72d93bf
# 26 https://matterhorn.dce.harvard.edu/engage/player/watch.html?id=8003c1bc-80a3-44f0-a578-21a5985810f8
# 27 https://matterhorn.dce.harvard.edu/engage/player/watch.html?id=0ea5e572-f2da-4f3f-b54b-df4edf9a1106
# 28 https://matterhorn.dce.harvard.edu/engage/player/watch.html?id=cdb6ae4c-a4ea-434d-a0c3-cdff3c2cd645
# 29 https://matterhorn.dce.harvard.edu/engage/player/watch.html?id=4012362e-1090-47e3-904b-7e835f57d77b
# 30 https://matterhorn.dce.harvard.edu/engage/player/watch.html?id=b2ac047a-ff65-4926-bd4a-77fdf1c63e0f
# 31 https://matterhorn.dce.harvard.edu/engage/player/watch.html?id=145018c2-260e-47dc-b965-bfdfafacd4e9
# 32 https://matterhorn.dce.harvard.edu/engage/player/watch.html?id=697ce8bd-a41c-45d4-8201-5e0dcc8a518c
# 33 https://matterhorn.dce.harvard.edu/engage/player/watch.html?id=afee98e6-4ca0-4319-9336-fbae46755f1a
# 34 https://matterhorn.dce.harvard.edu/engage/player/watch.html?id=3cd5e34b-803f-4f64-ba25-95b67797daad
# 35 https://matterhorn.dce.harvard.edu/engage/player/watch.html?id=cf9c4d5f-fe87-48cc-bd45-3da212b39a95
# 36 https://matterhorn.dce.harvard.edu/engage/player/watch.html?id=4dc7719e-1ef4-4ee5-a9d9-fc48c3e13185
# 37 https://matterhorn.dce.harvard.edu/engage/player/watch.html?id=62b95e14-c296-44da-9691-446dfa313836
# 38 https://matterhorn.dce.harvard.edu/engage/player/watch.html?id=f7ff1893-fbf7-4909-b44e-12e61a98a677
# 39 https://matterhorn.dce.harvard.edu/engage/player/watch.html?id=e15f221c-5275-4f7f-b486-759a7d483bc8

# %% [markdown]
# > Note: Rename **prefix** as per where you want videos saved!

# %%
# make filename, add to tuple in wanted list
convert_mth = {'Dec':'12', 'Nov':'11', 'Oct':'10', 'Sep':'09'}
final_names = []
prefix = '../../../../../../BUFFALO/Harvard/vids/'
for n,d,w in wanted_list:
    d1 = d.split()
    final_names.append((n,d,w, 
                        prefix + convert_mth[d1[1]] + d1[0] + ' - ' + n.split()[0] + ' ' + n.split()[1] + '.mp4'))
final_names[0]
# Out:
# ('Final Project Presentations (CAPTIONS)',
#  '16 Dec 2:30AM',
#  'https://matterhorn.dce.harvard.edu/engage/player/watch.html?id=b721f1db-9c16-464b-bcd3-3d81e7cd13a1',
#  '../../../../../../BUFFALO/Harvard/vids/1216 - Final Project.mp4')

# %%
# make a dict to store webbys
webby_dict = {}

for i in xrange(39):
    if i < 9:
        file_name = "Vid HTMLS/0%d.html" % (i + 1)
    else:
        file_name = "Vid HTMLS/%d.html" % (i + 1)

    # open file
    content, vid_links = None, []
    with open(file_name, 'r') as f:
        content = f.read()
    content = bs4.BeautifulSoup(content)

    # get links as a list
    vid_links = [l.get('src') for l in content.findAll('source', {'type':"video/mp4"})]
    webby_dict[final_names[i]] = vid_links
    
webby_dict.items()[0]

# format of dict : (name, date, web_viewer website, name of save file) = [main_video, slides_video]
# Out:
# (('Lecture 17 Advanced Bayesian Thinking. (CAPTIONS)',
#   '30 Oct 1:30AM',
#   'https://matterhorn.dce.harvard.edu/engage/player/watch.html?id=35282cbd-94b3-4fd7-bd5e-b3a8f40e72b1',
#   '../../../../../../BUFFALO/Harvard/vids/1030 - Lecture 17.mp4'),
#  ['https://da4w749qm6awt.cloudfront.net/engage-player/35282cbd-94b3-4fd7-bd5e-b3a8f40e72b1/25d2319e-a727-46ea-a6eb-97dc6309ca71/presenter_delivery.mp4',
#   'https://da4w749qm6awt.cloudfront.net/engage-player/35282cbd-94b3-4fd7-bd5e-b3a8f40e72b1/1a2f075f-d54b-4679-a985-ea774816a660/presentation_delivery.mp4'])

# %%
webby_keys = webby_dict.keys()
# sorts by date 
webby_keys = sorted(webby_keys, key=lambda x : convert_mth[x[1].split()[1]] + x[1].split()[0])
webby_keys[38]
# Out:
# ('Final Project Presentations (CAPTIONS)',
#  '16 Dec 2:30AM',
#  'https://matterhorn.dce.harvard.edu/engage/player/watch.html?id=b721f1db-9c16-464b-bcd3-3d81e7cd13a1',
#  '../../../../../../BUFFALO/Harvard/vids/1216 - Final Project.mp4')

# %%
# get a few files at a time (worried about storage capacity)
test = urllib.URLopener()

for n in xrange(39):
    dl_list = webby_dict[webby_keys[n]]
    dl_name = webby_keys[n][3]
    dl_name_slides = webby_keys[n][3][:-4] + ' (slides).mp4'
    # get the first vid
    print 'starting DL #%d ...' % n
    test.retrieve(dl_list[0], dl_name)
    # get the second vid (some don't have)
    print 'starting slides DL #%d ...' % n
    try: 
        test.retrieve(dl_list[1], dl_name_slides)
        print "completed!"
    except: 
        print "no slides, completed!"
        pass
# Out:
# IndexErrorTraceback (most recent call last)
# <ipython-input-8-55472fb15f1d> in <module>()
#       3
#       4 for n in xrange(39,40):
# ----> 5     dl_list = webby_dict[webby_keys[n]]
#       6     dl_name = webby_keys[n][3]
#       7     dl_name_slides = webby_keys[n][3][:-4] + ' (slides).mp4'
#
# IndexError: list index out of range

# %% [markdown]
# > You have saved all vids till index 13!

# %% [markdown]
# ## Scraping Basics - the Lecture 2 way

# %%
## all imports
from IPython.display import HTML
import numpy as np
import urllib2
import bs4 #this is beautiful soup
import time
import operator
import socket
import cPickle
import re # regular expressions

from pandas import Series
import pandas as pd
from pandas import DataFrame

import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns
sns.set_context("talk")
sns.set_style("white")

# %%
url = "https://matterhorn.dce.harvard.edu/engage/ui/index.html#/2016/01/14328"
source = urllib2.urlopen(url).read()
har_main = bs4.BeautifulSoup(source)
print har_main.prettify()
# Out:
# <!DOCTYPE html>
# <html data-ng-app="pubListApp" lang="en" xmlns="http://www.w3.org/1999/xhtml">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#   <meta content="HUDCE Publication Listing" name="description"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <title>
#    Publication Listing
#   </title>
#   <link href="combined/css/ocDcePubListing.css" rel="stylesheet"/>
#  </head>
#  <body>
#   <!-- Distance Education Header and banner  -->
#   <div class="banner {{school}}" data-ng-class="{'embedded':embedded || ltitool}" id="header-banner">
#    <!-- Generalized Harvard (Summer/Extension agnostic) Header -->
#    <div class="topbar">
#     <div id="topbar-flex">
#      <a href="http://www.harvard.edu/" title="The Harvard University web page">
#       <span class="topbar__logo i-harvard-logo ir">
#        Harvard University
#       </span>
#      </a>
#      <div id="report-a-problem">
#       <a href="//cm.dce.harvard.edu/forms/report.shtml?server=MH&amp;offeringId={{seriesId}}" title="Link to Report A Problem Form">
#        Report A
#             Problem
#       </a>
#      </div>
#     </div>
#    </div>
#   </div>
#   <div data-ng-view="ng-view" id="listing-body">
#    <noscript>
#     <div class="container">
#      <div class="de-messages">
#       JavaScript is disabled on your browser. Enable JavaScript in order to view the course listing.
#      </div>
#     </div>
#    </noscript>
#   </div>
#   <div data-ng-class="{'embedded':embedded || ltitool}" id="footer">
#    <div>
#     <div id="footer-privacy">
#      <a href="http://www.{{school}}.harvard.edu/privacy-policy" title="Privacy policy">
#       Privacy Policy
#      </a>
#      |
#      <a href="#/tos" title="Terms of Use">
#       Terms of Use
#      </a>
#     </div>
#     <div id="footer-copyright">
#      ©
#      <span id="copyright-year">
#       2016
#      </span>
#      President and Fellows of Harvard College
#     </div>
#    </div>
#   </div>
#   <!-- END #footer -->
#   <!--[if lt IE 7]>
#       <p class="browsehappy">You are using an <strong>outdated</strong> browser. Please <a href="http://browsehappy.com/">upgrade your browser</a> to improve your experience.</p>
#   <![endif]-->
#   <div data-app-version="app-version" style="display:none">
#   </div>
#   <script src="combined/bower_components/angular/angular.js">
#   </script>
#   <script src="combined/bower_components/angular-route/angular-route.js">
#   </script>
#   <script src="combined/bower_components/angular-resource/angular-resource.js">
#   </script>
#   <script src="combined/bower_components/angular-sanitize/angular-sanitize.js">
#   </script>
#   <script src="combined/bower_components/moment/moment.js">
#   </script>
#   <script src="combined/bower_components/moment-timezone/moment-timezone-with-data-2010-2020.js">
#   </script>
#   <script src="combined/app.js">
#   </script>
#   <script src="combined/views/seriesview/seriesview.js">
#   </script>
#   <script src="combined/views/publistview/publistview.js">
#   </script>
#   <script src="combined/components/version/version.js">
#   </script>
#   <script src="combined/components/version/version-directive.js">
#   </script>
#   <script src="combined/components/version/interpolate-filter.js">
#   </script>
#   <script src="combined/components/combojs/services.js" type="text/javascript">
#   </script>
#   <script src="combined/components/combojs/liveFilter.js" type="text/javascript">
#   </script>
#   <script src="combined/components/combojs/liveTimerDirective.js" type="text/javascript">
#   </script>
#   <script src="combined/components/combojs/refreshService.js" type="text/javascript">
#   </script>
#   <script src="combined/components/combojs/dataTransformService.js" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    var copyrightyear = document.getElementById('copyright-year');
#     if (copyrightyear) {
#       copyrightyear.innerHTML = new Date().getFullYear();
#     }
#   </script>
#  </body>
# </html>
# /home/ratio/anaconda2/lib/python2.7/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 174 of the file /home/ratio/anaconda2/lib/python2.7/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))

# %% [markdown]
# Page is implemented with Javascript! What to do?
#
# I turned to [this guy](https://impythonist.wordpress.com/2015/01/06/ultimate-guide-for-scraping-javascript-rendered-web-pages/) for some help. Here's his method ..
#
# ## Scraping Javascript pages
#
# 1. Install PyQT4
#
# >  `sudo apt-get install python-qt4`
#
#     Unfortunately, instructions use pyqt4. We have pyqt-5 on our build. Can the instructions be modified?

# %%
import sys

# contains the core classes, including the event loop and Qt’s signal and slot mechanism. It also includes platform independent abstractions for animations, state machines, threads, mapped files, shared memory, regular expressions, and user and application settings.
from PyQt5.QtCore import *
# contains classes for windowing system integration, event handling, 2D graphics, basic imaging, fonts and text. It also containes a complete set of OpenGL and OpenGL ES bindings
from PyQt5.QtGui import *
# QtWebKit contains classes for a WebKit2 based implementation of a web browser.
from PyQt5.QtWebKit import *
from PyQt5.QtWebKitWidgets import *
from PyQt5.QtWidgets import *

# %%
# impythonista

class Render(QWebPage):  
    def __init__(self, url):  
        self.app = QApplication(sys.argv)  
        QWebPage.__init__(self)  
        self.loadFinished.connect(self._loadFinished)  
        self.mainFrame().load(QUrl(url))  
        self.app.exec_()  

    def _loadFinished(self, result):  
        self.frame = self.mainFrame()  
        self.app.quit()

# %%
# IMPYTHONISTA

url = "https://matterhorn.dce.harvard.edu/engage/player/watch.html?id=b721f1db-9c16-464b-bcd3-3d81e7cd13a1"
r1 = Render(url)
# result is a QString.
result = r1.frame.toHtml()
print type(result)
# Out:
# <type 'unicode'>

# %%
import bs4
har_main = bs4.BeautifulSoup(result)
print har_main.prettify()
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <meta content="text/html; charset=utf-8;" http-equiv="Content-type"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="initial-scale=1.0" name="viewport"/>
#   <title>
#    DCE Video Player
#   </title>
#   <script src="javascript/swfobject.js" type="text/javascript">
#   </script>
#   <script src="javascript/base.js" type="text/javascript">
#   </script>
#   <script src="javascript/jquery.js" type="text/javascript">
#   </script>
#   <script src="javascript/lunr.min.js" type="text/javascript">
#   </script>
#   <!-- DCE additional js start -->
#   <script src="mh_dce_resources/js/jquery-ui.min.js" type="text/javascript">
#   </script>
#   <script src="resources/bootstrap/js/bootstrap.min.js" type="text/javascript">
#   </script>
#   <!-- DCE additional js end -->
#   <!-- DCE adding require back in, UPV uses it to pull in dashjs -->
#   <script src="javascript/require.js" type="text/javascript">
#   </script>
#   <script src="javascript/paella_player.js" type="text/javascript">
#   </script>
#   <script src="javascript/app-index.js" type="text/javascript">
#   </script>
#   <link charset="utf-8" href="resources/bootstrap/css/bootstrap.slate.min.css" media="screen" rel="stylesheet" type="text/css"/>
#   <!-- DCE additional css start -->
#   <link href="mh_dce_resources/style/jquery-ui.min.css" rel="stylesheet" type="text/css"/>
#   <link href="resources/style/opencast_cs50.css" rel="stylesheet" type="text/css"/>
#   <!-- DCE additional css end -->
#   <!-- DCE style_cs50.css as default paellaSkin, also set in config -->
#   <link charset="utf-8" href="resources/style/style_cs50.css" id="paellaSkin" media="screen" rel="stylesheet" title="no title" type="text/css"/>
#   <script>
#    // Sample implementation of the authentication URL callback.
# 			// Put the callback name in config.json, auth.authCallbackName
# 			function authenticationUrl(redirect) {
# 				redirect = redirect ? "?redirect=" + encodeURIComponent(redirect): "";
# 				return "https://www.upv.es/auth" + redirect;
# 			}
#
# 			// Sample implementation of the user data callback
# 			// Put the callback name in config,json, auth.userDataCallbackName
# 			function videoData(onSuccess) {
# 				onSuccess({
# 					permissions: {
# 						canRead: true,
# 						canContribute: false,
# 						canWrite: false,
# 						loadError: false,
# 						isAnonymous: true
# 					},
# 					userData: {
# 						username: 'anonymous',
# 						name: 'Anonymous',
# 						avatar: 'resources/images/default_avatar.png'
# 					}
# 				});
# 			}
#
# 			// Sample configuration to use this callbacks:
# 			/*
#
# 			 "auth":{
# 			 	"authCallbackName":"authenticationUrl",
# 			 	"userDataCallbackName":"videoData"
# 			 }
# 			 */
#   </script>
#  </head>
#  <body id="body" onload="loadOpencastPaellaDCE('playerContainer');;">
#   <div id="playerContainer" style="display:block;width:100%">
#   </div>
#  </body>
# </html>

# %% [markdown]
# Problem : browser outdated.
#
# Attempting [stack overflow](https://stackoverflow.com/questions/35241872/how-to-download-from-javascript-rendered-webpage) method

# %%
import sys

from PyQt5.QtWebKitWidgets import QWebPage
from PyQt5.QtWidgets import QApplication

class Render(QWebPage):
    """Render HTML with PyQt5 WebKit."""

    def __init__(self, html):
        self.html = None
        print 1
        self.app = QApplication(sys.argv)
        print 2
        QWebPage.__init__(self)
        print 3
        self.loadFinished.connect(self._loadFinished)
        print 4
        self.mainFrame().setHtml(html)
        print 5
        self.app.exec_() # Spending a long time here
        print 6

    def _loadFinished(self, result):
        print 7
        self.html = self.mainFrame().toHtml()
        print 8
        self.app.quit()
        print 9

url = "https://matterhorn.dce.harvard.edu/engage/player/watch.html?id=b721f1db-9c16-464b-bcd3-3d81e7cd13a1"
print 'beginning render'
r1 = Render(url).html
print 'rendered, beg b4'
import bs4
har_main = bs4.BeautifulSoup(r1)
print har_main.prettify()
# Out:
# beginning render
# 1
# 2
# 3
# 4
# 7
# 8
# 9
# 5

# %% [markdown]
# Seems to get stuck loading.
#
# Okay. What if we didn't scrape the main page, since it's a one off thing, and just copied in the html?
